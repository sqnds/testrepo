# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Warattha Kangwanwongsakul </b> <br>
# Architect

# %% [markdown]
# <i> I am interested in data science because i like to discover new insight from data </i>

# %% [markdown]
# ### The following code tests some basic math

# %%
1+1
# Out:
# 2

# %% [markdown]
# <ol>
# <li> Jan </li>
# <li> Feb </li>
# <li> Mar </li>
# </ol>
# <hr> <br>
# - Bullet 1
# - Bullet 2
# <hr>
#
# <table style="width=20%">
# <tr>
#     <th>Name</th>
#     <th>Age</th>
#     <th>Salary</th>
#     </tr>
#
# <tr>
#     <td>Ben</td>
#     <td>26</td>
#     <td>80k</td>
#     </tr>
#
# <tr>
#     <td>Sand</td>
#     <td>25</td>
#     <td>27k</td>
#     </tr>
